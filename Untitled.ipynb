# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)

# %%
pulsar <- read_csv("pulsar_data/HTRU_2.csv", 
                   col_names = c("M_IP","SD_IP","EK_IP","SK_IP","M_DM_SNR","SD_DM_SNR","EK_DM_SNR","SK_DM_SNR","CLASS")) |>
                mutate(CLASS = as_factor(CLASS))
pulsar
# Out:
# Rows: 17898 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (9): M_IP, SD_IP, EK_IP, SK_IP, M_DM_SNR, SD_DM_SNR, EK_DM_SNR, SK_DM_SN...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#       M_IP     SD_IP    EK_IP      SK_IP       M_DM_SNR   SD_DM_SNR EK_DM_SNR
# 1     140.5625 55.68378 -0.2345714 -0.6996484  3.199833   19.11043   7.975532
# 2     102.5078 58.88243  0.4653182 -0.5150879  1.677258   14.86015  10.576487
# 3     103.0156 39.34165  0.3233284  1.0511644  3.121237   21.74467   7.735822
# ⋮     ⋮        ⋮        ⋮          ⋮           ⋮          ⋮         ⋮
# 17896 119.3359 59.93594 0.1593631  -0.74302540  21.430602 58.87200   2.499517
# 17897 114.5078 53.90240 0.2011614  -0.02478884   1.946488 13.38173  10.007967
# 17898  57.0625 85.79734 1.4063910   0.08951971 188.306020 64.71256  -1.597527
#       SK_DM_SNR  CLASS
# 1      74.24222  0
# 2     127.39358  0
# 3      63.17191  0
# ⋮     ⋮          ⋮
# 17896   4.595173 0
# 17897 134.238910 0
# 17898   1.429475 0

# %%
pulsar_summarize <- pulsar|>
            group_by(CLASS)|>
            summarize(across(M_IP:SK_DM_SNR, mean))
pulsar_summarize
# Out:
#   CLASS M_IP      SD_IP    EK_IP     SK_IP     M_DM_SNR  SD_DM_SNR EK_DM_SNR
# 1 0     116.56273 47.33974 0.2104401  0.380844  8.863258 23.28798  8.862674
# 2 1      56.69061 38.71060 3.1306554 15.553576 49.825995 56.46896  2.757069
#   SK_DM_SNR
# 1 113.62034
# 2  17.93173

# %%
set.seed(6)

pulsar_split <- initial_split(pulsar, prop = 0.8, strata = CLASS)
pulsar_train <- training(pulsar_split)   
pulsar_test <- testing(pulsar_split)
pulsar_train
pulsar_test
# Out:
#       M_IP      SD_IP    EK_IP      SK_IP       M_DM_SNR   SD_DM_SNR EK_DM_SNR
# 1     102.50781 58.88243 0.46531815 -0.5150879  1.6772575  14.860146 10.57649
# 2      88.72656 40.67223 0.60086608  1.1234917  1.1789298  11.468720 14.26957
# 3     119.48438 48.76506 0.03146022 -0.1121676  0.9991639   9.279612 19.20623
# ⋮     ⋮         ⋮        ⋮          ⋮           ⋮          ⋮         ⋮
# 14316 119.3359  59.93594 0.1593631  -0.74302540  21.430602 58.87200   2.499517
# 14317 114.5078  53.90240 0.2011614  -0.02478884   1.946488 13.38173  10.007967
# 14318  57.0625  85.79734 1.4063910   0.08951971 188.306020 64.71256  -1.597527
#       SK_DM_SNR  CLASS
# 1     127.3936   0
# 2     252.5673   0
# 3     479.7566   0
# ⋮     ⋮          ⋮
# 14316   4.595173 0
# 14317 134.238910 0
# 14318   1.429475 0
#      M_IP      SD_IP    EK_IP       SK_IP      M_DM_SNR  SD_DM_SNR EK_DM_SNR
# 1    140.5625  55.68378 -0.23457141 -0.6996484 3.199833  19.11043  7.975532
# 2    103.0156  39.34165  0.32332837  1.0511644 3.121237  21.74467  7.735822
# 3    136.7500  57.17845 -0.06841464 -0.6362384 3.642977  20.95928  6.896499
# ⋮    ⋮         ⋮        ⋮           ⋮          ⋮         ⋮         ⋮
# 3578 121.37500 53.24516  0.1037722  -0.3651187 1.0953177 12.239976 16.25804
# 3579  98.72656 50.40782  0.5651236   0.2452309 0.5702341  9.011285 22.01859
# 3580 136.42969 59.84742 -0.1878456  -0.7381230 1.2968227 12.166062 15.45026
#      SK_DM_SNR CLASS
# 1    74.24222  0
# 2    63.17191  0
# 3    53.59366  0
# ⋮    ⋮         ⋮
# 3578 303.8800  0
# 3579 561.8338  0
# 3580 285.9310  0

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_mip <- pulsar_train |>
                ggplot(aes(x = M_IP, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Mean Integrated Profile", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_mip
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_sdip <- pulsar_train |>
                ggplot(aes(x = SD_IP, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Standard deviation of the integrated profile", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_sdip
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_ekip <- pulsar_train |>
                ggplot(aes(x = EK_IP, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Excess kurtosis of the integrated profile", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_ekip
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_skip <- pulsar_train |>
                ggplot(aes(x = SK_IP, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Skewness of the integrated profile", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_skip
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_m_dm_snr <- pulsar_train |>
                ggplot(aes(x = M_DM_SNR, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Mean of the DM-SNR curve", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_m_dm_snr
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_sd_dm_snr <- pulsar_train |>
                ggplot(aes(x = SD_DM_SNR, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Standard deviation of the DM-SNR curve", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_sd_dm_snr
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_ek_dm_snr <- pulsar_train |>
                ggplot(aes(x = EK_DM_SNR, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Excess kurtosis of the DM-SNR curve", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_ek_dm_snr
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
type_labels <- c("0" = "Non-Pulsar", "1" = "Pulsar")
pulsar_plot_sk_dm_snr <- pulsar_train |>
                ggplot(aes(x = SK_DM_SNR, fill = CLASS)) +
                geom_histogram() +
                facet_grid(rows = vars(CLASS),
                          labeller = labeller(CLASS = type_labels)) +
                labs(x = "Skewness of the DM-SNR curve", fill = "Type") +
                scale_fill_manual(labels = c("Non-pulsar", "Pulsar"),
                                 values = c("orange2", "steelblue")) +
                theme(text = element_text(size = 20))
pulsar_plot_sk_dm_snr
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
